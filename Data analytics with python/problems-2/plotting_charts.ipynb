# %%
import pandas_bokeh
import pandas
from bokeh.plotting import figure
data = pandas.read_excel("PROBLEM 1.xlsx", parse_dates=["START DATE"])
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure, show, output_file
# from bokeh.plotting.glyph_api import GlyphAPI

# %%
data
# Out:
#               TRAINEE       TASK ID         SUBJECT  \
# 0    Naresh Chepuroju  NC2021102467           KAFKA
# 1    Naresh Chepuroju  NC2021102668           KAFKA
# 2    Naresh Chepuroju  NC2021102769           KAFKA
# 3    Naresh Chepuroju  NC2021103170           MySql
# 4      Giridhar Yerra    YG20211024  DATA ANALYTICS
# 5      Giridhar Yerra    YG20211026  DATA ANALYTICS
# 6      Giridhar Yerra  YG2021102801  DATA ANALYTICS
# 7      Giridhar Yerra  YG2021102802           MySql
# 8      Giridhar Yerra    YG20211029  DATA ANALYTICS
# 9      Giridhar Yerra  YG2021103001  DATA ANALYTICS
# 10    Swapna Koyagura  SN2021102414        HTML&CSS
# 11    Swapna Koyagura  SN2021102801           MySql
# 12    Swapna Koyagura  SN2021102902           MySql
# 13    Swapna Koyagura  SN2021103003           MySql
# 14  Mamatha Tekumatla  MT2021102462         ANGULAR
# 15  Mamatha Tekumatla  MT2021102663         ANGULAR
# 16  Mamatha Tekumatla  MT2021102764         ANGULAR
# ...

# %% [markdown]
# noOfTasks

# %%
s = data.groupby(["TRAINEE", "SUBJECT"]).sum()
s1 = s.index.to_numpy()
s["names"] = s1
s
# Out:
#                                   NO OF TASKS  \
# TRAINEE           SUBJECT
# Amulya Madupoju   HTML&CSS                  1
#                   MySql                     2
# Giridhar Yerra    DATA ANALYTICS            5
#                   MySql                     1
# KORUKONDA HARISH  AWS LAMBDA                7
# Mamatha Tekumatla ANGULAR                   7
# Naresh Chepuroju  KAFKA                     3
#                   MySql                     1
# Swapna Koyagura   HTML&CSS                  1
#                   MySql                     3
# Vamshi Bhairoju   HTML&CSS                  2
#                   MySql                     2
# valisetti suresh  KAFKA                     7
#
#                                                              names
# TRAINEE           SUBJECT
# Amulya Madupoju   HTML&CSS             (Amulya Madupoju, HTML&CSS)
#                   MySql                   (Amulya Madupoju, MySql)
# ...

# %%
u= data.groupby(["TRAINEE"])
# v["TRAINEES"] = v1
# v.
#data[(data["SUBJECT"]=="PYTHON") & (data["MONTH"] == ("09"))]
# v2 = {n: n*n for n in v1}
# v2

# %%
z= data.groupby(["SUBJECT"])

# %%
r = data.groupby(["SUBJECT"]).sum()
r1 = r.index.tolist()
r1
# Out:
# ['ANGULAR', 'AWS LAMBDA', 'DATA ANALYTICS', 'HTML&CSS', 'KAFKA', 'MySql']

# %%
s.plot_bokeh.bar(ylabel="value per unit", alpha=0.7)
# Out:
# Figure(id='1038', ...)

# %%
output_file("plot.html")

# %%
# p = figure(x_range=fruits, height=250, title="Fruit Counts by Year",
#            toolbar_location=None, tools="hover", tooltips="$name @fruits: @$name")

# p.vbar_stack(years, x='fruits', width=0.9, color=colors, source=data,
#              legend_label=years

source = ColumnDataSource(data=dict(z=z, r= r["NO OF TASKS"]))

# %%
f =figure( x_range=z, y_range=(0,10), plot_width=300, plot_height= 300, title="noOfTasks",toolbar_location=None, tools="hover")

# %%
f.vbar(u, x=u, width=0.9, source=source,legend_label=u)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4300/2040090989.py in <module>
# ----> 1 f.vbar(u, x=u, width=0.9, source=source,legend_label=u)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bokeh\plotting\_decorators.py in wrapped(self, *args, **kwargs)
#      84             if self.coordinates is not None:
#      85                 kwargs.setdefault("coordinates", self.coordinates)
# ---> 86             return create_renderer(glyphclass, self.plot, **kwargs)
#      87
#      88         wrapped.__signature__ = Signature(parameters=sigparams)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bokeh\plotting\_renderer.py in create_renderer(glyphclass, plot, **kwargs)
#      94     incompatible_literal_spec_values += _process_sequence_literals(glyphclass, glyph_visuals, source, is_user_source)
# ...

# %%
show(f)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1204', ...)

# %%
filtered_data = data[data["SUBJECT"]=="MySql"]
filtered_data
# Out:
#              TRAINEE       TASK ID SUBJECT                  MODULE  \
# 3   Naresh Chepuroju  NC2021103170   MySql   Indroduction to MySql
# 7     Giridhar Yerra  YG2021102802   MySql                     DLS
# 11   Swapna Koyagura  SN2021102801   MySql         create database
# 12   Swapna Koyagura  SN2021102902   MySql               operators
# 13   Swapna Koyagura  SN2021103003   MySql  sql command categories
# 29   Amulya Madupoju    AM20211029   MySql    sql basics and Mysql
# 30   Amulya Madupoju    AM20211030   MySql            Sql commands
# 40   Vamshi Bhairoju  VS2021103001   MySql    sql basics and Mysql
# 41   Vamshi Bhairoju  VS2021103102   MySql            Sql commands
#
#                                            TOPIC NAME TOPIC ID  START DATE  \
# 3                      Creating Schemas,adding tables   MS0001  31/11/2021
# 7                   create tables, columns, .........  MYSQL01  28/10/2021
# ...

# %%
h = filtered_data.groupby(['TRAINEE']).sum()
h.index.tolist()
# Out:
# ['Amulya Madupoju',
#  'Giridhar Yerra',
#  'Naresh Chepuroju',
#  'Swapna Koyagura',
#  'Vamshi Bhairoju']

# %%
h.plot_bokeh.bar(ylabel="values per unit", alpha = 0.6, plot_width= 300, title = "MYSQL in a week")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4992/1989436586.py in <module>
# ----> 1 h.plot_bokeh.bar(ylabel="values per unit", alpha = 0.6, plot_width= 300, title = "MYSQL in a week")
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_bokeh\plot.py in bar(self, x, y, **kwds)
#    2031             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    2032         """
# -> 2033         return self(kind="bar", x=x, y=y, **kwds)
#    2034
#    2035     def barh(self, x=None, y=None, **kwds):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_bokeh\plot.py in __call__(self, *args, **kwargs)
#    1783
#    1784     def __call__(self, *args, **kwargs):
# -> 1785         return plot(self.df, *args, **kwargs)
#    1786
#    1787     @property
#
# ...

# %%
b = figure(x_range=h.index.tolist(), height=450, toolbar_location=None, tools="")

# %%
b.vbar(x=h, ylabel="values per unit", width=0.9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4116/3861433044.py in <module>
# ----> 1 b.vbar(x=h, ylabel="values per unit", width=0.9)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bokeh\plotting\_decorators.py in wrapped(self, *args, **kwargs)
#      84             if self.coordinates is not None:
#      85                 kwargs.setdefault("coordinates", self.coordinates)
# ---> 86             return create_renderer(glyphclass, self.plot, **kwargs)
#      87
#      88         wrapped.__signature__ = Signature(parameters=sigparams)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bokeh\plotting\_renderer.py in create_renderer(glyphclass, plot, **kwargs)
#     114     muted_visuals = pop_visuals(glyphclass, kwargs, prefix='muted_', defaults=glyph_visuals, override_defaults={'alpha':0.2})
#     115
# ...
