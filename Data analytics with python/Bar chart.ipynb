# %% [markdown]
# ## BAR CHART TABLEAU IN PYTHON

# %%
import pandas
from datetime import datetime
import matplotlib.pyplot as plt
data = pandas.read_excel("PROBLEM 1.xlsx")
data4 = pandas.read_excel("Book1 spend hours.xlsx")
data46 = pandas.read_excel("Spend Time.xlsx")

# %%
plt.pie(data4['Spend Hours'], labels=data4['Courses'])
# Out:
# ([<matplotlib.patches.Wedge at 0x241545c6a30>,
# ...
#  [Text(0.9140922361963753, 0.6119112547792451, 'Python'),
#   Text(-0.2025607676993732, 1.081188760295371, 'React'),
#   Text(-0.9462780839796866, 0.5608545156987982, 'Kafka'),
#   Text(-1.0995859774035999, 0.030177446833189753, 'Aws'),
#   Text(-0.690883342897988, -0.8559674097219481, 'React Native'),
#   Text(0.3197643485159015, -1.0524973925944907, 'Mysql'),
#   Text(0.7589213863468376, -0.7962652380616614, 'Html/css'),
#   Text(1.0456948431274415, -0.34135362171313727, 'Data Analytics(Tableau)')])

# %%
tasks = data.groupby(['TRAINEE'])['SUBJECT'].count()
plt.figure(figsize=(17, 7))
plt.bar(tasks.index, tasks)
# Out:
# <BarContainer object of 8 artists>

# %%
tasks
# Out:
# TRAINEE
# Amulya Madupoju      3
# Giridhar Yerra       6
# KORUKONDA HARISH     7
# Mamatha Tekumatla    7
# Naresh Chepuroju     4
# Swapna Koyagura      4
# Vamshi Bhairoju      4
# valisetti suresh     7
# Name: SUBJECT, dtype: int64

# %%
plt.figure(figsize=(18, 7))
plt.plot(data46['Start Date'],data46['Spend Time'])

# %%
data.head()

# %%
data.columns
# Out:
# Index(['TRAINEE', 'TASK ID', 'SUBJECT', 'MODULE', 'TOPIC NAME', 'TOPIC ID',
#        'START DATE', 'END DATE', 'NO OF TASKS', 'MySql'],
#       dtype='object')

# %%
data.hist('NO OF TASKS')
# Out:
# array([[<AxesSubplot:title={'center':'NO OF TASKS'}>]], dtype=object)

# %%
data['NO OF TASKS']

# %%
DATA = data[['TRAINEE', 'SUBJECT', 'NO OF TASKS', 'MySql']]
DATA

# %%
data_analysis = data.groupby(['START DATE'])['NO OF TASKS'].count()
data_analysis
# Out:
# START DATE
# 24/10/2021    7
# 26/10/2021    7
# 27/10/2021    4
# 28/10/2021    4
# 29/10/2021    4
# 30/10/2021    4
# 31/10/2021    4
# Name: NO OF TASKS, dtype: int64
