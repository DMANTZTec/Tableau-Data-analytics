# %%
import pandas as pd
import numpy as np
import streamlit as st
import mysql.connector
from mysql.connector import connection
from sqlalchemy import create_engine

# %%
mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "swapna2021",
    database = "ecomm"
)

# %% [markdown]
# productSkuDf

# %%
cursor = mydb.cursor()

queryproductSkuDf = "SELECT * FROM ecomm.product_sku"

cursor.execute("SELECT * FROM ecomm.product_sku")

sku = cursor.fetchall()
 
productSkuDf = pd.read_sql(queryproductSkuDf, mydb)

productSkuDf
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\1393311070.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   productSkuDf = pd.read_sql(queryproductSkuDf, mydb)
#     product_sku_id avg_customer_rating                   image_url  price  \
# 0              346                None              toor_dal_1.jpg  100.0
# 1              349                None              toor_dal_1.jpg  180.0
# 2              364                None          green_gram_001.jpg   10.0
# 3              367                None          green_gram_001.jpg  180.0
# 4              374                None              desi_ghee1.jpg  300.0
# 5              380                None              desi_ghee1.jpg  600.0
# 6              400                None               chana_dal.jpg   80.0
# ...

# %%
productSkuCostDf = (productSkuDf.groupby(['product_sku_id', 'product_sku_cd', 'product_id'])['price'].sum()).reset_index()

productSkuCostDf
# Out:
#     product_sku_id  product_sku_cd  product_id  price
# 0              346        TOORDAL1         343  100.0
# 1              349        TOORDAL2         343  180.0
# 2              364       MOONGDAL2         361   10.0
# 3              367        MOONGDAL         361  180.0
# 4              374         GHEE001         370  300.0
# 5              380         GHEE001         370  600.0
# 6              400       CHANNADAL         398   80.0
# 7              403     CHANNADAL01         398   40.0
# 8              409         CARROTS         406   50.0
# 9              412         CARROTS         406  100.0
# 10             418        POTATOES         415   30.0
# 11             421        POTATOES         415   15.0
# 12             427     CAULIFLOWER         424   20.0
# 13             430     CAULIFLOWER         424   40.0
# 14             436        TOMATOES         433   50.0
# 15             439        TOMATOES         433   25.0
# ...

# %% [markdown]
# productDf

# %%
cursor1 = mydb.cursor()

queryproductDf = "SELECT * FROM ecomm.product"

cursor1.execute("SELECT * FROM ecomm.product")

product = cursor1.fetchall()

# productDf = pd.read_sql(queryproductDf, mydb)
productDf = pd.read_sql_query("SELECT * FROM ecomm.product", mydb)

productDf
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\2188399169.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   productDf = pd.read_sql_query("SELECT * FROM ecomm.product", mydb)
#     product_id            product_desc            product_name  \
# 0          343                Toor Dal                Toor Dal
# 1          361               Moong Dal               Moong Dal
# 2          370               Desi Ghee               Desi Ghee
# 3          398              Channa Dal              Channa Dal
# 4          406                 Carrots                 Carrots
# 5          415                Potatoes                Potatoes
# 6          424             Cauliflower             Cauliflower
# 7          433                Tomatoes                Tomatoes
# 8          442             Green Beans             Green Beans
# ...

# %% [markdown]
# productSkuRatingDf

# %%
cursor3 = mydb.cursor()

queryproductSkuRatingDf = "SELECT * FROM ecomm.product_sku_customer_ratings"

cursor3.execute(queryproductSkuRatingDf)

skuRating = cursor3.fetchall()

# productSkuRatingDf = pd.DataFrame(skuRating)
productSkuRatingDf = pd.read_sql(queryproductSkuRatingDf, mydb)

productSkuRatingDf
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\1858244438.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   productSkuRatingDf = pd.read_sql(queryproductSkuRatingDf, mydb)
#      id  customer_id                                           feedback  \
# 0     1            1                                       Good proudct
# 1     2            2                          It's good quality fabric.
# 2     3            3  however I ordered the usual size but it dis no...
# 3     4            4                                       I FEEL UNFIT
# 4     5            5                                      Overall good.
# 5     6            6        Very nice colour and material is also good.
# 6     7            7                          good quality and good fit
# ...

# %% [markdown]
# orderItemDf

# %%
cursor4 = mydb.cursor()

queryorderItemDf = "SELECT * FROM ecomm.order_item"

cursor4.execute(queryorderItemDf)

orderItem = cursor4.fetchall()

# orderItemDf = pd.DataFrame(orderItem)
orderItemDf = pd.read_sql(queryorderItemDf, mydb)

orderItemDf
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\27656594.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orderItemDf = pd.read_sql(queryorderItemDf, mydb)
#     order_item_id discount_applied gift_wrapped mrp_price  order_id   price  \
# 0             204                0          yes       600       203   600.0
# 1             205               no          yes       700       203   700.0
# 2             206               no          yes    3000.0       203  1500.0
# 3             207               no          yes       750       203   750.0
# 4             209                0          yes       600       208   600.0
# 5             210               no          yes       890       208   890.0
# 6             211               no          yes       575       208   575.0
# ...

# %% [markdown]
# orderStatusDf

# %%
cursor5 = mydb.cursor()

queryorderStatusDf = "SELECT * FROM ecomm.order_status"

cursor5.execute("SELECT * FROM ecomm.order_status")

orderStatus = cursor5.fetchall()

orderStatusDf = pd.read_sql(queryorderStatusDf, mydb)

orderStatusDf
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\587422765.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orderStatusDf = pd.read_sql(queryorderStatusDf, mydb)
#      order_track_ref comment date_sent      estimated_time  latitude  \
# 0                  1    None      None 2020-01-02 16:52:01       0.0
# 1                  2    None      None 2020-01-01 16:54:51       0.0
# 2                  3    None      None 2020-01-02 16:54:51       0.0
# 3                  4    None      None 2020-01-01 16:58:58       0.0
# 4                  5    None      None 2020-01-03 16:59:10       0.0
# ..               ...     ...       ...                 ...       ...
# 566              567    None      None 2023-02-10 10:36:45       0.0
# 567              568    None      None 2023-02-11 10:36:45       0.0
# ...

# %% [markdown]
# ordersDf

# %%
cursor6 = mydb.cursor()

queryordersDf ="SELECT * FROM ecomm.orders"

cursor6.execute("SELECT * FROM ecomm.orders")

orders = cursor6 .fetchall()

ordersDf = pd.read_sql(queryordersDf, mydb)

ordersDf
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\1153254612.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ordersDf = pd.read_sql(queryordersDf, mydb)
#     order_id coupon_applied   customer_id  delivery_person_id order_mod_dt_tm  \
# 0        203       NoCoupon         rohit                   0            None
# 1        208       NoCoupon  shanti putta                   0            None
# 2        213       NoCoupon         rohit                   0            None
# 3        216       NoCoupon         rohit                   0            None
# 4        221       NoCoupon  shanti putta                   0            None
# 5        223       NoCoupon         rohit                   0            None
# 6        226       NoCoupon          Prem                   0            None
# ...

# %%
cursor7 = mydb.cursor()

queryorderStatusRef = "SELECT * FROM ecomm.order_status_ref"

cursor7.execute("SELECT * FROM ecomm.order_status_ref")

orderStatusRef = cursor7.fetchall()

orderStatusRefDf = pd.read_sql(queryorderStatusRef, mydb)

orderStatusRefDf
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\1340150132.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orderStatusRefDf = pd.read_sql(queryorderStatusRef, mydb)
#    status_id       status_code
# 0         10           Ordered
# 1         11        Fulfilling
# 2         12           Packing
# 3         13           Shipped
# 4         14  Out For Delivery
# 5         15         Delivered
# 6         16          Canceled

# %%
orderStatusDf = pd.read_sql_query("SELECT * FROM ecomm.order_status", mydb)

filteredOrdersDf = (orderStatusDf[['order_id', 'status_cd', 'order_track_update_time']])

filteredOrdersDf['ordered_date'] = (orderStatusDf['order_track_update_time'].dt.date)

# filteredOrdersDf['year'] = ((orderStatusDf['order_track_update_time'].dt.year).replace(np.nan, 0)).astype(int)


filteredOrdersDf

# for year in list(filteredOrdersDf['year']):
#     years = []
#     date = map(int, year)
#     years.append([date])

# # years

# years = [[year] for year in list(filteredOrdersDf['year'])]
# Out:
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\751423461.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orderStatusDf = pd.read_sql_query("SELECT * FROM ecomm.order_status", mydb)
# C:\Users\ADMIN_2\AppData\Local\Temp\ipykernel_22456\751423461.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredOrdersDf['ordered_date'] = (orderStatusDf['order_track_update_time'].dt.date)
#      order_id         status_cd order_track_update_time ordered_date
# 0           0  Out For Delivery     2019-12-24 16:52:01   2019-12-24
# ...
